# %%
import pandas
import pathlib
import pydantic

# %%
# 1 st Create YOur directory 
GLOBAL = r'C:\Users\Marvin Garcia\Desktop\end_to_end_titanic_ml'
DATASETLOCATION = "data"
TRAIN_MODEL = ""
PACKAGE_ROOT = pathlib.Path(GLOBAL).resolve() #no parten
#CONFIG_FILE_PATH
DATASET_DIR = PACKAGE_ROOT / DATASETLOCATION   # Data Training/Testing
TRAINED_MODEL_DIR = PACKAGE_ROOT / TRAIN_MODEL # Data to keep Model

# %%
DATA_DIR = 'train.csv'

DATASET_DIR = PACKAGE_ROOT / DATASETLOCATION   # Data Training/Testing





def load_data(filename:str) -> pd.DataFrame:
    dataframe = pandas.read_csv(pathlib.Path(DATASET_DIR,filename))  
    return dataframe

load_data(DATA_DIR)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
load_data(DATA_DIR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-6078a5cc95f2> in <module>
# ----> 1 load_data(DATA_DIR)
#
# TypeError: load_data() takes 0 positional arguments but 1 was given

# %%
PACKAGE_ROOT.resolve()
# Out:
# WindowsPath('C:/Users/Marvin Garcia/Desktop/end_to_end_titanic_ml')

# %%
DATA_DIR = 'test.csv'

pandas.read_csv(pathlib.Path(DATASET_DIR,DATA_DIR))
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
